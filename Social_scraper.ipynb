# %%
# !pip install facebook-scraper
# !pip install git+https://github.com/kevinzg/facebook-scraper.git
# Out:
# ...
#      |████████████████████████████████| 133kB 38.4MB/s
# ...
#      |████████████████████████████████| 286kB 36.1MB/s
# ...
#      |████████████████████████████████| 92kB 12.7MB/s
# ...
#      |████████████████████████████████| 81kB 11.4MB/s
# ...
#      |████████████████████████████████| 143kB 53.0MB/s
# ...
#      |████████████████████████████████| 81kB 11.6MB/s
# ...
#   Created wheel for demjson: filename=demjson-2.2.4-cp37-none-any.whl size=73566 sha256=8a2baa9ff277b6e0788fe17c3fb36af582128e820c0b79e8497c1f2788eb1291
#   Stored in directory: /root/.cache/pip/wheels/c5/d2/ab/a54fb5ea53ac3badba098160e8452fa126a51febda80440ded
# ...
#   Created wheel for parse: filename=parse-1.19.0-cp37-none-any.whl size=24592 sha256=5990af1fd06514d6bf5568b19e9257a80c4f8dd8ed80f7e7dce4665dda0b1a5d
#   Stored in directory: /root/.cache/pip/wheels/c0/39/ea/e2fd678bd130953f5438470b8dfa529f00787e9b8b92b27467
# ...

# %%
import urllib.request

# %%
from facebook_scraper import get_posts
#credentials timepass hai you can use it anytime 
for post in get_posts('nintendo', pages=1,credentials= ('user_id' ,'password')):
  print(post['text'][:50])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: UserWarning: A low page limit (<=2) might return no results, try increasing the limit
#   exec(code_obj, self.user_global_ns, self.user_ns)
# May 2021 is in the books! Take a look back at just

# %%
from facebook_scraper import get_group_info
get_group_info("latesthairstyles",credentials= ('user_id' ,'password'))
# Out:
# {'admins': [{'link': '/africanstylemagazinecom/',
#    'name': 'African Style Magazine'},
#   {'link': '/connectfluencer/', 'name': 'Everythingbrightandbeautiful'},
#   {'link': '/Kaakakigroup/', 'name': 'Kaakaki Group'},
#   {'link': '/opentohelp/', 'name': 'Open to Help'}],
#  'id': '579169815767106',
#  'members': [{'link': '/adedotunadesanya', 'name': 'Sam Ade'},
#   {'link': '/rinene.okim', 'name': 'Rinene Okim'}],
#  'name': 'HAIRSTYLES',
#  'type': 'पब्लिक ग्रुप'}

# %%
name = ['BillGates','zuck']
from facebook_scraper import get_profile
for i in name:
  print(get_profile(str(i),credentials= ('user_id' ,'password')))  #friends=True
  print("--------")
# Out:
# {'Name': 'Bill Gates - परिचय'}
# --------
# ...

# %% [markdown]
# Instagram

# %%
# !pip install instagram-scraper
# Out:
# ...
#      |████████████████████████████████| 389kB 32.9MB/s
# ...
#      |████████████████████████████████| 3.3MB 42.4MB/s
# ...
#      |████████████████████████████████| 26.9MB 159kB/s
# ...
#   Created wheel for instagram-scraper: filename=instagram_scraper-1.9.1-cp37-none-any.whl size=35944 sha256=b160bc0e3e351de511d9ba9796b87e6778d6b987f416b7cdd9da8684fb7d9d3f
#   Stored in directory: /root/.cache/pip/wheels/65/b5/0a/90c1b539b2f4baa66e816f34a87e8416a7ad7e641adf9377ba
# ...
#   Created wheel for moviepy: filename=moviepy-1.0.3-cp37-none-any.whl size=110745 sha256=9da14a3240b9547948ca11ade1dd313774bb89d9e8b6d1594b9cc31a3296248a
#   Stored in directory: /root/.cache/pip/wheels/e0/fe/1c/f4e6dca9e828d4b979c04e461d7fcc5b8e7bd35f947e665b65
# ...
#   Created wheel for proglog: filename=proglog-0.1.9-cp37-none-any.whl size=6158 sha256=f6210e4601cad086aa4f44a9f81fd5229ad2db56a7980ad7afd12fe185c309ba
#   Stored in directory: /root/.cache/pip/wheels/65/56/60/1d0306a8d90b188af393c1812ddb502a8821b70917f82dcc00
# ...

# %%
! pip install instagram-scraper --upgrade
# Out:
# Requirement already up-to-date: instagram-scraper in /usr/local/lib/python3.7/dist-packages (1.9.1)
# ...

# %%
# !git clone https://github.com/arc298/instagram-scraper.git
# Out:
# Cloning into 'instagram-scraper'...
# remote: Enumerating objects: 1468, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 1468 (delta 1), reused 3 (delta 1), pack-reused 1460
# Receiving objects: 100% (1468/1468), 420.01 KiB | 21.00 MiB/s, done.
# Resolving deltas: 100% (892/892), done.

# %%
# !python /content/instagram-scraper/setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating instagram_scraper.egg-info
# writing instagram_scraper.egg-info/PKG-INFO
# writing dependency_links to instagram_scraper.egg-info/dependency_links.txt
# writing entry points to instagram_scraper.egg-info/entry_points.txt
# writing requirements to instagram_scraper.egg-info/requires.txt
# writing top-level names to instagram_scraper.egg-info/top_level.txt
# writing manifest file 'instagram_scraper.egg-info/SOURCES.txt'
# reading manifest file 'instagram_scraper.egg-info/SOURCES.txt'
# writing manifest file 'instagram_scraper.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# ...
#
# creating build
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying instagram_scraper.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# ...

# %%
# !instagram-scraper --help -h
# Out:
# usage: instagram-scraper [-h] [--destination DESTINATION]
#                          [--login-user LOGIN_USER] [--login-pass LOGIN_PASS]
#                          [--followings-input]
#                          [--followings-output FOLLOWINGS_OUTPUT]
#                          [--filename FILENAME] [--quiet] [--maximum MAXIMUM]
#                          [--retain-username] [--media-metadata]
#                          [--profile-metadata] [--proxies PROXIES]
#                          [--include-location]
#                          [--media-types MEDIA_TYPES [MEDIA_TYPES ...]]
#                          [--latest] [--latest-stamps LATEST_STAMPS]
#                          [--cookiejar COOKIEJAR] [--tag]
#                          [--filter [FILTER [FILTER ...]]]
#                          [--filter-location [FILTER_LOCATION [FILTER_LOCATION ...]]]
#                          [--filter-location-file FILTER_LOCATION_FILE]
# ...

# %%
# !instagram-scraper id_to_extract_Data -u user_id -p password
# Out:
# Searching amb_buj for profile pic: 100% 1/1 [00:00<00:00, 2240.55 images/s]
# Searching amb_buj for stories: 100%|##########| 97/97 [00:00<00:00, 11203.29 media/s]
# Searching amb_buj for broadcasts: 0 media [00:00, ? media/s]
# Searching amb_buj for posts: 10 media [00:03,  3.18 media/s]
# Downloading: 100%|##########| 108/108 [00:06<00:00, 16.92it/s]

# %%
# !instagram-scraper bts -u user_id -p password --maximum 50
# Out:
# Searching bts for profile pic: 100% 1/1 [00:00<00:00, 2385.84 images/s]
# Searching bts for stories: 0 media [00:00, ? media/s]
# Searching bts for broadcasts: 0 media [00:00, ? media/s]
# Searching bts for posts: 1 media [00:04,  4.31s/ media]
# Downloading: 100%|##########| 51/51 [00:02<00:00, 23.70it/s]

# %%
# !pip install instagramy

# %%
# !pip install instagramy --upgrade
# Out:
# Requirement already up-to-date: instagramy in /usr/local/lib/python3.7/dist-packages (4.4)

# %%
from instagramy import InstagramUser

session_id = "xxxxxxxxxxxxxxxxxxxxxxx"
user = InstagramUser('nike', sessionid=session_id)
print(user.is_verified)
print(user.biography)
print(user.user_data)
# Out:
# True
# Spotlighting athlete* and 👟 stories
# #BlackLivesMatter and #StopAsianHate
# ...
